# %%
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable as sm

# %%
df = pd.read_csv("/mnt/home/user43/Sophie_Bep/Resultaten/Error.csv", skipinitialspace=True, index_col=0)

# %%
A = df[df['Klimaat'].isin(['Af', 'Aw', 'Am'])]
B = df[df['Klimaat'].isin(['BWh', 'BWk', 'BSh', 'BSk'])]
C = df[df['Klimaat'].isin(['Csa', 'Csb', 'Csc', 'Cwa', 'Cwb', 'Cwc', 'Cfa', 'Cfb', 'Cfc'])]
D = df[df['Klimaat'].isin(['Dsa', 'Dsb', 'Dsc', 'Dsd','Dwa', 'Dwb', 'Dwc', 'Dwd','Dfa', 'Dfb', 'Dfc', 'Dfd'])]
E = df[df['Klimaat'].isin(['ET', 'EF'])]

# %%
Amat1 = np.array([[A.loc['MY-PSO', 'MEdag'], A.loc['BR-Sa1', 'MEdag'], A.loc['BR-Npw', 'MEdag']]])
Amat2 = np.array([[A.loc['MY-PSO', 'RMSEdag'], A.loc['BR-Sa1', 'RMSEdag'], A.loc['BR-Npw', 'RMSEdag']]])

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(20,10))
fig.suptitle('A', y=0.7, fontsize=16)

cax1 = ax[0].matshow(Amat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
ax[0].set_title('Mean Error\n')
fig.colorbar(cax1, ax=ax[0], orientation='vertical',extend='both', shrink= 0.4)
ax[0].set_xticklabels(['']+['f', 'm','w'])
ax[0].set_yticklabels([''])

cax2 = ax[1].matshow(Amat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
ax[1].set_title('Root Mean Squared Error \n')
fig.colorbar(cax2, ax=ax[1], orientation='vertical',extend='both', shrink= 0.4)
ax[1].set_xticklabels(['']+['f', 'm','w'])
ax[1].set_yticklabels([''])
plt.savefig('/mnt/home/user43/Sophie_Bep/Resultaten/Afbeeldingen/A.jpg')

# %%
Bmat1 = np.array([[B.loc['SD-Dem', 'MEdag'], B.loc['AU-Cpr', 'MEdag']],
                  [B.loc['ZA-Kru', 'MEdag'], B.loc['ES-LJu', 'MEdag']]])
Bmat2 = np.array([[B.loc['SD-Dem', 'RMSEdag'], B.loc['AU-Cpr', 'RMSEdag']],
                  [B.loc['ZA-Kru', 'RMSEdag'], B.loc['ES-LJu', 'RMSEdag']]])

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(15,10))
fig.suptitle('B',  y=0.85,fontsize=16)

cax1 = ax[0].matshow(Bmat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
ax[0].set_title('Mean Error\n')
fig.colorbar(cax1, ax=ax[0], orientation='vertical',extend='both', shrink= 0.7)
ax[0].set_xticklabels(['']+['h', 'k'])
ax[0].set_yticklabels(['']+['W', 'S'])

cax2 = ax[1].matshow(Bmat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
ax[1].set_title('Root Mean Squared Error \n')
fig.colorbar(cax2, ax=ax[1], orientation='vertical',extend='both',  shrink= 0.7)
ax[1].set_xticklabels(['']+['h', 'k'])
ax[1].set_yticklabels(['']+['W', 'S'])
plt.savefig('/mnt/home/user43/Sophie_Bep/Resultaten/Afbeeldingen/B.jpg')

# %%
Cmat1 = np.array([[C.loc['FR-Pue', 'MEdag'], C.loc['ES-LgS', 'MEdag'], np.nan],
                  [C.loc['ZM-Mon', 'MEdag'], np.nan, np.nan],
                  [C.loc['US-ARM', 'MEdag'], C.loc['NL-Loo', 'MEdag'],np.nan]])
Cmat2 = np.array([[C.loc['FR-Pue', 'RMSEdag'], C.loc['ES-LgS', 'RMSEdag'], np.nan],
                  [C.loc['ZM-Mon', 'RMSEdag'], np.nan, np.nan],
                  [C.loc['US-ARM', 'RMSEdag'], C.loc['NL-Loo', 'RMSEdag'],np.nan]])

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(15,10))
fig.suptitle('C',  y=0.85,fontsize=16)

cax1 = ax[0].matshow(Cmat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
ax[0].set_title('Mean Error\n')
fig.colorbar(cax1, ax=ax[0], orientation='vertical',extend='both', shrink= 0.7)
ax[0].set_xticklabels(['']+['a', 'b', 'c'])
ax[0].set_yticklabels(['']+['s', 'w', 'f'])

cax2 = ax[1].matshow(Cmat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
ax[1].set_title('Root Mean Squared Error \n')
fig.colorbar(cax2, ax=ax[1], orientation='vertical',extend='both',  shrink= 0.7)
ax[1].set_xticklabels(['']+['a', 'b', 'c'])
ax[1].set_yticklabels(['']+['s', 'w', 'f'])
plt.savefig('/mnt/home/user43/Sophie_Bep/Resultaten/Afbeeldingen/C.jpg')

# %%
Dmat1 = np.array([[np.nan, D.loc['US-Me2', 'MEdag'], np.nan, np.nan],
                  [D.loc['CN-Cng', 'MEdag'], D.loc['CN-Cha', 'MEdag'], D.loc['CN-Ha2', 'MEdag'], np.nan],
                  [D.loc['US-MMS', 'MEdag'], D.loc['US-Ha1', 'MEdag'], D.loc['US-NR1', 'MEdag'],np.nan]])
Dmat2 = np.array([[np.nan, D.loc['US-Me2', 'RMSEdag'], np.nan, np.nan],
                  [D.loc['CN-Cng', 'RMSEdag'], D.loc['CN-Cha', 'RMSEdag'], D.loc['CN-Ha2', 'RMSEdag'], np.nan],
                  [D.loc['US-MMS', 'RMSEdag'], D.loc['US-Ha1', 'RMSEdag'], D.loc['US-NR1', 'RMSEdag'],np.nan]])

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(15,10))
fig.suptitle('D',  y=0.85,fontsize=16)

cax1 = ax[0].matshow(Dmat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
ax[0].set_title('Mean Error\n')
fig.colorbar(cax1, ax=ax[0], orientation='vertical',extend='both', shrink= 0.7)
ax[0].set_xticklabels(['']+['a', 'b', 'c', 'd'])
ax[0].set_yticklabels(['']+['s', 'w', 'f'])

cax2 = ax[1].matshow(Dmat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
ax[1].set_title('Root Mean Squared Error \n')
fig.colorbar(cax2, ax=ax[1], orientation='vertical',extend='both',  shrink= 0.7)
ax[1].set_xticklabels(['']+['a', 'b', 'c', 'd'])
ax[1].set_yticklabels(['']+['s', 'w', 'f'])
plt.savefig('/mnt/home/user43/Sophie_Bep/Resultaten/Afbeeldingen/D.jpg')

# %%
Emat1 = np.array([[E.loc['CH-Dav', 'MEdag'], np.nan]])
Emat2 = np.array([[E.loc['CH-Dav', 'RMSEdag'], np.nan]])

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(20,10))
fig.suptitle('E', y=0.7, fontsize=16)

cax1 = ax[0].matshow(Emat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
ax[0].set_title('Mean Error\n')
fig.colorbar(cax1, ax=ax[0], orientation='vertical',extend='both', shrink= 0.4)
ax[0].set_xticklabels(['']+['T', 'F'])
ax[0].set_yticklabels([''])

cax2 = ax[1].matshow(Emat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
ax[1].set_title('Root Mean Squared Error \n')
fig.colorbar(cax2, ax=ax[1], orientation='vertical',extend='both', shrink= 0.4)
ax[1].set_xticklabels(['']+['T', 'F'])
ax[1].set_yticklabels([''])
plt.savefig('/mnt/home/user43/Sophie_Bep/Resultaten/Afbeeldingen/E.jpg')

# %%
fig, ax = plt.subplots(nrows=5, ncols=2,figsize=(10,5), gridspec_kw={'height_ratios': [1, 3,3,2.25,1.5]})
fig.tight_layout()
cax1 = ax[0, 0].matshow(Amat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
ax[0,0].set_title('ME', fontsize=20)
fig.colorbar(cax1, ax=ax[:,0], orientation='vertical',extend='both')
ax[0,0].set_xticklabels(['']+['f', 'm','w'])
ax[0,0].set_yticklabels(['']+['x'], color='white')
ax[0,0].set_ylabel('A', rotation=0, fontsize=20, va='center', labelpad=28)

cax2 = ax[0,1].matshow(Amat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
ax[0,1].set_title('RMSE', fontsize=20)
fig.colorbar(cax2, ax=ax[:,1], orientation='vertical',extend='both')
ax[0,1].set_xticklabels(['']+['f', 'm','w'])
ax[0,1].set_yticklabels([''])
ax[0,1].set_ylabel('A', rotation=0, fontsize=20, va='center', labelpad=28)

cax1 = ax[1,0].matshow(Bmat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
# ax[1,0].set_title('Mean Error\n')
# fig.colorbar(cax1, ax=ax[1,0], orientation='vertical',extend='both', shrink= 0.7)
ax[1,0].set_xticklabels(['']+['h', 'k'])
ax[1,0].set_yticklabels(['']+['W', 'S'])
ax[1,0].set_ylabel('B', rotation=0, fontsize=20, va='center',labelpad=25)

cax2 = ax[1,1].matshow(Bmat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
# ax[1,1].set_title('Root Mean Squared Error \n')
# fig.colorbar(cax2, ax=ax[1,1], orientation='vertical',extend='both',  shrink= 0.7)
ax[1,1].set_xticklabels(['']+['h', 'k'])
ax[1,1].set_yticklabels(['']+['W', 'S'])
ax[1,1].set_ylabel('B', rotation=0, fontsize=20, va='center', labelpad=25)

cax1 = ax[2,0].matshow(Cmat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
# ax[2,0].set_title('Mean Error\n')
# fig.colorbar(cax1, ax=ax[2,0], orientation='vertical',extend='both', shrink= 0.7)
ax[2,0].set_xticklabels(['']+['a', 'b', 'c'])
ax[2,0].set_yticklabels(['']+['s', 'w', 'f'])
ax[2,0].set_ylabel('C', rotation=0, fontsize=20, va='center',labelpad=25)

cax2 = ax[2,1].matshow(Cmat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
# ax[2,1].set_title('Root Mean Squared Error \n')
# fig.colorbar(cax2, ax=ax[2,1], orientation='vertical',extend='both',  shrink= 0.7)
ax[2,1].set_xticklabels(['']+['a', 'b', 'c'])
ax[2,1].set_yticklabels(['']+['s', 'w', 'f'])
ax[2,1].set_ylabel('C', rotation=0, fontsize=20, va='center', labelpad=25)

cax1 = ax[3,0].matshow(Dmat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
# ax[3,0].set_title('Mean Error\n')
# fig.colorbar(cax1, ax=ax[3,0], orientation='vertical',extend='both', shrink= 0.7)
ax[3,0].set_xticklabels(['']+['a', 'b', 'c', 'd'])
ax[3,0].set_yticklabels(['']+['s', 'w', 'f'])
ax[3,0].set_ylabel('D', rotation=0, fontsize=20, va='center',labelpad=25)

cax2 = ax[3,1].matshow(Dmat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
# ax[3,1].set_title('Root Mean Squared Error \n')
# fig.colorbar(cax2, ax=ax[3,1], orientation='vertical',extend='both',  shrink= 0.7)
ax[3,1].set_xticklabels(['']+['a', 'b', 'c', 'd'])
ax[3,1].set_yticklabels(['']+['s', 'w', 'f'])
ax[3,1].set_ylabel('D', rotation=0, fontsize=20, va='center',labelpad=25)

cax1 = ax[4,0].matshow(Emat1, cmap = 'RdBu', vmin=-0.9, vmax=0.9)
# ax[4,0].set_title('Mean Error\n')
# fig.colorbar(cax1, ax=ax[4,0], orientation='vertical',extend='both', shrink= 0.4)
ax[4,0].set_xticklabels(['']+['T', 'F'])
ax[4,0].set_yticklabels(['']+['x'], color='white')
ax[4,0].set_ylabel('E', rotation=0, fontsize=20, va='center',labelpad=28)

cax2 = ax[4,1].matshow(Emat2, cmap = 'RdYlGn_r', vmin=0.6, vmax=1.6)
# ax[4,1].set_title('Root Mean Squared Error \n')
# fig.colorbar(cax2, ax=ax[4,1], orientation='vertical',extend='both', shrink= 0.4)
ax[4,1].set_xticklabels(['']+['T', 'F'])
ax[4,1].set_yticklabels([''])
ax[4,1].set_ylabel('E', rotation=0, fontsize=20, va='center', labelpad=28)
fig.savefig('/mnt/home/user43/Sophie_Bep/Resultaten/Afbeeldingen/Alles.jpg', bbox_inches='tight')
